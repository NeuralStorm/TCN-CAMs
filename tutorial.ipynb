# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import tqdm

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np    

from model import tcn
from visualize import get_cams, plot_cams
from trainer import train
import scipy.io

# %%
#Train on MNIST Dataset for visualization
net, testloader = train()
# Out:
# cuda
# Epoch: 0, Loss: 0.904: 100%|██████████| 7500/7500 [00:28<00:00, 263.65it/s]
# Test accuracy: 0.09146666666666667
# ...
# Epoch: 5, Loss: 0.226: 100%|██████████| 7500/7500 [00:28<00:00, 262.32it/s]
# Test accuracy: 0.1318
# ...
# Epoch: 10, Loss: 0.142: 100%|██████████| 7500/7500 [00:28<00:00, 259.12it/s]
# Test accuracy: 0.13491666666666666
# ...
# Epoch: 15, Loss: 0.119: 100%|██████████| 7500/7500 [00:27<00:00, 275.46it/s]
# Test accuracy: 0.14063333333333333
# ...
# Epoch: 20, Loss: 0.113: 100%|██████████| 7500/7500 [00:28<00:00, 266.53it/s]
# Test accuracy: 0.1428
# ...
# Epoch: 25, Loss: 0.103: 100%|██████████| 7500/7500 [00:27<00:00, 273.52it/s]
# Test accuracy: 0.14261666666666667
# ...
# Epoch: 30, Loss: 0.094: 100%|██████████| 7500/7500 [00:27<00:00, 273.87it/s]
# Test accuracy: 0.14188333333333333
# ...
# Epoch: 35, Loss: 0.086: 100%|██████████| 7500/7500 [00:27<00:00, 274.67it/s]
# Test accuracy: 0.14405
# ...
# Epoch: 40, Loss: 0.075: 100%|██████████| 7500/7500 [00:27<00:00, 274.90it/s]
# Test accuracy: 0.1448
# ...

# %%
#Load MNIST Dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5), (0.5)), # Normalizes to [-1, 1]
    transforms.Lambda(lambda x: x.view(x.shape[0], -1)) 
])
trainset = torchvision.datasets.MNIST(root='.', train=True,
                            download=True, transform = transform)
trainloader = torch.utils.data.DataLoader(trainset, shuffle = True)

# %%
#Visualize a sample image and it's CAM for the correct label
for singleTrial, labels in trainloader:
    fig, ax = plt.subplots()
    heatmap = sns.heatmap(np.reshape(singleTrial, (28,28)), cmap=sns.color_palette("Spectral", as_cmap=True), ax=ax, cbar=False)
    figure = heatmap.get_figure()  
    plt.show()
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    plt.clf()
    
    print(device)
    singleTrial = singleTrial.to(device)
    outputs, cams = net(singleTrial, generateCAMs = True)
    print(outputs)
    fig, ax = plt.subplots()
    x = 42
    y = 27
    depad = 20
    cams = cams.cpu().detach().numpy()[0][labels]
    cams = np.reshape(cams[depad:depad + x * y], (y,x))
    
    heatmap = sns.heatmap(cams, cmap=sns.color_palette("Spectral", as_cmap=True), ax=ax, cbar=False)
    figure = heatmap.get_figure()  
    plt.show()
    break
# Out:
# torch.Size([1, 1, 784])
# cuda
# tensor([[-11.2782,   4.6725,   4.5912,   0.4027,   3.5884,  -0.4007,  -3.4478,
#            8.5377,  -8.9433,   2.8173]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
